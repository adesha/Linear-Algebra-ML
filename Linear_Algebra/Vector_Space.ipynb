# %%
import numpy as np
import matplotlib.pyplot as plt
import math
a=np.array([1,2])
b=np.array([3,2])
c=a+b
d=a-b
origin=np.array([[0,0,0,0],[0,0,0,0]])
plt.quiver(*origin,[a[0],b[0],c[0],d[0]],[a[1],b[1],c[1],d[1]],color=['000000','r','g','b'],scale=17)
plt.show()
